# %% [markdown]
# <img style="float: left;;" src='Figures/alinco.png' /></a>
#
# # <center> <font color= #000047> Actividad 2: librería Pandas.</font>
# ___

# %% [markdown]
# ### Utilizando el archivo [titanic.csv], realice lo que se le pide:

# %% [markdown]
# **1. Generar un DataFrame con los datos del fichero.**

# %% [markdown]
# **2. Mostrar por pantalla las dimensiones del DataFrame, el número de datos que contiene, los nombres de sus columnas y filas, los tipos de datos de las columnas, las 10 primeras filas y las 10 últimas filas.**

# %%
import pandas as pd
df_titanic = pd.read_csv('Data/titanic.csv')
df_titanic #Dimensiones del DataFrame (891 registros X 12 columnas), 891 regsitros, nombres de columnas y filas
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.info() #Mostrar tipo de dato de las columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_titanic.head(10) #10 primeras filas
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df_titanic.sort_values(by='PassengerId', ascending=False).head(10) #10 últimas filas
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 890          891         0       3                       Dooley, Mr. Patrick
# 889          890         1       1                     Behr, Mr. Karl Howell
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 887          888         1       1              Graham, Miss. Margaret Edith
# 886          887         0       2                     Montvila, Rev. Juozas
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 883          884         0       2             Banfield, Mr. Frederick James
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 881          882         0       3                        Markun, Mr. Johann
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# **3. Mostrar por pantalla los datos del pasajero con identificador 148.**

# %%
df_titanic[df_titanic['PassengerId'] == 148]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 147          148         0       3  Ford, Miss. Robina Maggie "Ruby"  female
#
#      Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 147  9.0      2      2  W./C. 6608  34.375   NaN        S

# %% [markdown]
# **4. Mostrar por pantalla las filas pares del DataFrame.**

# %%
df_titanic[df_titanic.index%2 == 0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **5. Mostrar por pantalla los nombres de las personas que iban en primera clase ordenadas alfabéticamente.**

# %%
df_titanic[df_titanic['Pclass'] == 1]['Name']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 23                          Sloper, Mr. William Thompson
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872                             Carlsson, Mr. Frans Olof
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887                         Graham, Miss. Margaret Edith
# 889                                Behr, Mr. Karl Howell
# Name: Name, Length: 216, dtype: object

# %% [markdown]
# **6. Mostrar por pantalla el porcentaje de personas que sobrevivieron y murieron.**

# %%
df_titanic.groupby('Survived')['Survived'].count() / len(df_titanic) * 100
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %% [markdown]
# **7. Mostrar por pantalla el porcentaje de personas que sobrevivieron en cada clase.**

# %%
sobrevivientes = df_titanic[df_titanic['Survived']==1]
sobrevivientes.groupby('Pclass')['Survived'].count() / len(df_titanic) * 100
# Out:
# Pclass
# 1    15.263749
# 2     9.764310
# 3    13.355780
# Name: Survived, dtype: float64

# %% [markdown]
# **8. Eliminar del DataFrame los pasajeros con edad desconocida.**

# %%
df_titanic = df_titanic.dropna(subset=['Age'])

# %% [markdown]
# **9. Mostrar por pantalla la edad media de las mujeres que viajaban en cada clase.**

# %%
mujeres = df_titanic[df_titanic['Sex']=='female']
mujeres.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    34.611765
# 2    28.722973
# 3    21.750000
# Name: Age, dtype: float64

# %% [markdown]
# **10.  Añadir una nueva columna booleana para ver si el pasajero era menor de edad o no.**

# %%
df_titanic['Under21'] = df_titanic['Age'].map(lambda x: 0 if x >= 21 else 1)
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **11.  Mostrar por pantalla el porcentaje de menores y mayores de edad que sobrevivieron en cada clase.**

# %%
sobrevivientes = df_titanic[df_titanic['Survived']==1]
agrupados = sobrevivientes.groupby(['Pclass','Under21']).size() 
porcentaje = (agrupados / len(df_titanic)) * 100
porcentaje
# Out:
# Pclass  Under21
# 1       0          14.705882
#         1           2.380952
# 2       0           7.983193
#         1           3.641457
# 3       0           6.442577
#         1           5.462185
# dtype: float64
